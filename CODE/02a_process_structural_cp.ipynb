# %% [markdown]
# ## Globals

# %%
from __future__ import print_function

import sys
import os
import re
import glob
import subprocess
import shutil
import json

#root_dir = '/home/preclineu/yartoe'
root_dir = '/project_cephfs/3022017.02/'
cluster_log_dir = os.path.join(root_dir,'logs')
aroma_path = '/home/preclineu/andmar/sfw/ICA-AROMA/ICA_AROMA.py'  

cmd_qsub_base = ['/home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py',
                 '-length', '102400',
                 '-memory', '32gb',
                 '-logfiledir', cluster_log_dir
                ]

abcd_dict = os.path.join(root_dir,'downloads','abcd_modalities.json')

# read the dictionary
with open(abcd_dict,'r') as f:
   modalities = json.load(f) 
    
# get a list of subjects to process
sub_dirs = sorted(glob.glob(os.path.join(root_dir,'subjects','sub-NDARINV*')))

#sub_dirs = sub_dirs[0:15]
#print('\n'.join(sub_dirs))

print('Dictionary read from:', abcd_dict)
print('Found', len(sub_dirs), 'subjects to process')
# Out:
# Dictionary read from: /project_cephfs/3022017.02/downloads/abcd_modalities.json
# Found 11856 subjects to process
# ['/project_cephfs/3022017.02/subjects/sub-NDARINV003RTV85',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV005V6D2C',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV007W6H7B',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV00BD7VDC',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV00CY2MDM',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV00HEV6HB',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV00J52GPG',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV00LH735Y',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV00LJVZK2',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV00NPMHND']

# %% [markdown]
# ## run fsl_anat

# %%
verbose = False

sub_batch = sub_dirs[:10]#[10000:]

submitted = 0
already_processed = 0
for s in sub_batch:
    subid = os.path.splitext(os.path.basename(s))[0]
    if verbose:
        print('processing subject',subid)

    job_name = 'ABCD_fsl_anat_' + subid
    
    sessions = glob.glob(os.path.join(s, 'ses-*'))
    for sess in sessions:
        sdir = os.path.join(sess, 'anat')
        if not os.path.exists(sdir):
            continue
        
        # get all subdirectories 
        t1_all = [os.path.join(sdir, o) for o in os.listdir(sdir) if os.path.isdir(os.path.join(sdir, o))]

        for t1_dir in t1_all:
            if os.path.exists(os.path.join(t1_dir,'T1.anat','T1_biascorr_brain.nii.gz')):
                if verbose: 
                    print(' >', subid, ' anatomical data already processed. Doing nothing')
                already_processed += 1
                continue
    
            cmd_fsl_anat = ['fsl_anat -i ', os.path.join(t1_dir,'T1.nii.gz')]
            cmd_str = '"%s"' % str(' '.join(cmd_fsl_anat)) 
            cmd_qsub = cmd_qsub_base + ['-name', job_name,'-command', cmd_str]

            #subprocess.Popen(' '.join(cmd_qsub), shell=True)
            
            submitted += 1
    
print('number of jobs submitted =', submitted)
print('number of T1s already processed =', already_processed)
# Out:
# number of jobs submitted = 4
# number of T1s already processed = 24

# %% [markdown]
# ## Select subjects (e.g. only those having 4 year follow-up)

# %%
target_ses = 'ses-4YearFollowUpYArm1'
target_ses = 'ses-2YearFollowUpYArm1'
#target_ses = 'ses-baselineYear1Arm1'

sub_list = []
sub_dirs_target = []
for s in sub_dirs:
    subid = os.path.splitext(os.path.basename(s))[0] 
    ses_dirs = glob.glob(os.path.join(s, 'ses-*'))
    
    sessions = list(map(os.path.basename, ses_dirs))
    if target_ses in sessions:
        sub_list.append(subid)
        sub_dirs_target.append(s)

print(len(sub_list), 'subjects found')
# Out:
# 7829 subjects found

# %%
sub_dirs_target
# Out:
# ['/project_cephfs/3022017.02/subjects/sub-NDARINV00CY2MDM',
#  '/project_cephfs/3022017.02/subjects/sub-NDARIN

#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3HMZ7DZZ',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3HU0G71U',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3HV5ZJLJ',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3HX1TNWP',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3HZG2Y7P',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3J1YYG4P',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3JUUH0FL',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3JYXAP1H',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3JZ6Y396',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3K0428FZ',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3K5PPAFD',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3KAPX6MY',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3KBYKMJ2',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3KYJ3920',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3LA2YW3R',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3LADRYDK',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3LL3C7PW',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3LMKTFHC',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3LT00AFX',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3LTP4JU7',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3MDCH394',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3MFBHV8Y',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3MLPX0CG',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3MTFEAAU',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3MTP07E9',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3N0KGZ5G',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3N6L8Z9U',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3NA8KUJ2',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3NABWF15',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3NGLDPCG',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3NKZ8EZX',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3NT6ML17',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3NXGCTWR',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3P1HLC7L',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3P1U2ABW',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3P72345Z',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3P7XHWPD',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3PB2GNLM',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3PH5L11X',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3PKXFBNU',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3PNCV5A7',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3PTPRFM5',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3R1XMUN2',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3R6TY43Y',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3RDMV5NE',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3RFU7ZRP',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3RLHYZEL',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3RTWYZX5',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3RXJAR68',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TBTUYZ5',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TFEMP67',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TG667EC',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TGTC3C9',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TKL2EYB',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TMCHLA7',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TRN51XL',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TT997HJ',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TUE7DV5',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3TYW27P3',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3U3CWTNF',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3UKGZNFG',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3UNMBY32',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3UPL5YML',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3UTXWW38',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3UZ9X88P',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3V253V18',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3V7GL5Z2',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3VAXZUWK',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3VGP47P6',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3VNNK2J3',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3VU4N68P',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3VX26MGH',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3W15L2YE',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3W3CHB2Y',
#  '/project_cephfs/3022017.02/subjects/sub-NDARINV3W5X0ZBG',
#  ...]

# %% [markdown]
# ## Run Freesurfer (cross-sectional)

# %%
num_processed = 0
num_failed = 0
num_submitted = 0
sub_no_t1 = []

verbose = False

default_t1_type = 'ABCD-T1-NORM'
log_prefix = 'ABCD_fs_'

#sub_batch = sub_dirs[100:]
sub_batch = sub_dirs_target

#fs_env = 'export FREESURFER_HOME=/opt/freesurfer/7.3.2'
fs_env = 'module load freesurfer/7.3.2'

cmd_qsub_fs = ['/home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py',
                 '-length', '202400',
                 '-memory', '5gb',
                 '-logfiledir', cluster_log_dir,
                 '-queue verylong'
                ]

print('Processing', len(sub_batch), 'subjects ...')
for s in sub_batch:
    subid = os.path.splitext(os.path.basename(s))[0] 
    
    sessions = glob.glob(os.path.join(s, 'ses-*'))
    for sess in sessions:
        sdir = os.path.join(sess, 'anat')
        sesid = os.path.basename(sess)
        full_subid = '_'.join((subid, sesid))
        
        if not os.path.exists(sdir):
            continue
        
        # get all subdirectories 
        t1_all = [os.path.join(sdir, o) for o in os.listdir(sdir) if os.path.isdir(os.path.join(sdir, o))]
        
        if len(t1_all) > 1:
            if verbose:
                print(' > Multiple t1s found for', full_subid, '(',len(t1_all), ') using default')
            
            # sub-select only ABCD-T1-NORM
            t1_all = [k for k in t1_all if default_t1_type in k]
            if len(t1_all) > 1:
                if verbose:
                    print(' > Failed.')
                continue;                        
        
        for t1_dir in t1_all:
            t1_file = os.path.join(t1_dir,'T1.nii.gz')            
            out_dir = os.path.join(root_dir, 'freesurfer', full_subid)
            
            if os.path.exists(out_dir):
                if os.path.exists(os.path.join(out_dir, 'stats', 'rh.w-g.pct.stats')):
                    # analysis is complete
                    if verbose:
                        print(' > Freesurfer already run for', full_subid,'doing nothing')
                    num_processed += 1
                    continue
                else:
                    # analysis did not complete
                    num_failed +=1
                    if verbose:
                        print(' > Freesurfer subject',full_subid,'found but failed. Continuing analysis')
                    cmd_fs = ['recon-all -s', full_subid, '-all','-qcache']
            else:
                # no analysis has been run
                if not os.path.exists(t1_file):
                    if verbose: 
                        print(' > No T1 found for sub', full_subid, '. Doing nothing')
                    sub_no_t1.append(subid)
                    continue
        
                cmd_fs = ['recon-all -i ', t1_file, '-s', full_subid, '-all','-qcache']
            
            #print(' '.join(cmd_fs))

            cmd_env = [fs_env + ' ; ',
                       'export SUBJECTS_DIR=' + os.path.join(root_dir,'freesurfer ; ')]
            cmd_str = '"%s"' % str(' '.join(cmd_env + cmd_fs)) 
            cmd_qsub = cmd_qsub_fs + ['-name', log_prefix + str(full_subid),'-command', cmd_str]
    
            num_submitted += 1
            #print(' '.join(cmd_qsub))
            subprocess.Popen(' '.join(cmd_qsub), shell=True)

print('jobs submitted =', num_submitted)       
print('number of subjects already processed =',num_processed)
print('number failed =',num_failed)
print('number without t1 =',len(sub_no_t1))

# %% [markdown]
# ## Create Freesurfer longitudinal templates
#
# Note: this needs to be run more carefully than the cross sectional approach above because it just clobbers the template directory.

# %%
bl
# Out:
# '/project_cephfs/3022017.02/subjects/sub-NDARINVZZZP87KR/ses-baselineYear1Arm1'

# %%
num_processed = 0
num_failed = 0
num_submitted = 0

verbose = False

log_prefix = 'ABCD_longfs_'

#sub_batch = sub_dirs[10:]
sub_batch = sub_dirs_target[5900:]

#fs_env = 'export FREESURFER_HOME=/opt/freesurfer/7.3.2'
fs_env = 'module load freesurfer/7.3.2'

cmd_qsub_fs = ['/home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py',
                 '-length', '202400',
                 '-memory', '5gb',
                 '-logfiledir', cluster_log_dir,
                 '-queue verylong'
                ]

print('Processing', len(sub_batch), 'subjects ...')
for s in sub_batch:
    subid = os.path.splitext(os.path.basename(s))[0] 
    
    cmd_fs = ['recon-all -base ', subid + '_long',]
    
    sessions = sorted(glob.glob(os.path.join(s, 'ses-*')))
    
    # make sure the baseline session is first 
    for i in range(len(sessions)):
        if 'baseline' in sessions[i]:
            bl = sessions[i]
            del sessions[i]
            sessions.insert(0, bl)
            continue
    
    good_sessions = 0 
    for sess in sessions:
        sesid = os.path.basename(sess)
        full_subid = '_'.join((subid, sesid))  
        fs_sess_dir = os.path.join(root_dir, 'freesurfer', full_subid)
        
        fs_sessions = []
        if os.path.exists(os.path.join(fs_sess_dir, 'stats', 'rh.w-g.pct.stats')):
            fs_sessions.append(full_subid)
        else:
            print(' > Freesurfer did not complete for', full_subid)
            continue
        
        cmd_fs += ['-tp', full_subid]
        good_sessions += 1
        
    if good_sessions < 2:
        print(' > Only one timepoint for', full_subid, 'aborting.')
        continue
        
    cmd_fs += ['-all', '-qcache']
        
    print(' '.join(cmd_fs))

    cmd_env = [fs_env + ' ; ',
               'export SUBJECTS_DIR=' + os.path.join(root_dir,'freesurfer ; ')]
    cmd_str = '"%s"' % str(' '.join(cmd_env + cmd_fs)) 
    cmd_qsub = cmd_qsub_fs + ['-name', log_prefix + str(subid + '_long'),'-command', cmd_str]
    num_submitted += 1
    print(' '.join(cmd_qsub))
    
    #subprocess.Popen(' '.join(cmd_qsub), shell=True)

print('jobs submitted =', num_submitted)       
print('number of subjects already processed =',num_processed)
print('number failed =',num_failed)
# Out:
# Processing 1929 subjects ...
#  > Freesurfer did not complete for sub-NDARINVR1927JG7_ses-2YearFollowUpYArm1
#  > Only one timepoint for sub-NDARINVR1927JG7_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR1JFZ70M_long -tp sub-NDARINVR1JFZ70M_ses-baselineYear1Arm1 -tp sub-NDARINVR1JFZ70M_ses-2YearFollowUpYArm1 -tp sub-NDARINVR1JFZ70M_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR1JFZ70M_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR1JFZ70M_long -tp sub-NDARINVR1JFZ70M_ses-baselineYear1Arm1 -tp sub-NDARINVR1JFZ70M_ses-2YearFollowUpYArm1 -tp sub-NDARINVR1JFZ70M_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR1KT1MAU_long -tp sub-NDARINVR1KT1MAU_ses-baselineYear1Arm1 -tp sub-NDARINVR1KT1MAU_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR1KT1MAU_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR1KT1MAU_long -tp sub-NDARINVR1KT1MAU_ses-baselineYear1Arm1 -tp sub-NDARINVR1KT1MAU_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR1TZTUN2_long -tp sub-NDARINVR1TZTUN2_ses-baselineYear1Arm1 -tp sub-NDARINVR1TZTUN2_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR1TZTUN2_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR1TZTUN2_long -tp sub-NDARINVR1TZTUN2_ses-baselineYear1Arm1 -tp sub-NDARINVR1TZTUN2_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR1Z0W0BH_long -tp sub-NDARINVR1Z0W0BH_ses-baselineYear1Arm1 -tp sub-NDARINVR1Z0W0BH_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR1Z0W0BH_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR1Z0W0BH_long -tp sub-NDARINVR1Z0W0BH_ses-baselineYear1Arm1 -tp sub-NDARINVR1Z0W0BH_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR20CKWHP_long -tp sub-NDARINVR20CKWHP_ses-baselineYear1Arm1 -tp sub-NDARINVR20CKWHP_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR20CKWHP_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR20CKWHP_long -tp sub-NDARINVR20CKWHP_ses-baselineYear1Arm1 -tp sub-NDARINVR20CKWHP_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR238YY1G_long -tp sub-NDARINVR238YY1G_ses-baselineYear1Arm1 -tp sub-NDARINVR238YY1G_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR238YY1G_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR238YY1G_long -tp sub-NDARINVR238YY1G_ses-baselineYear1Arm1 -tp sub-NDARINVR238YY1G_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR24ACBFH_long -tp sub-NDARINVR24ACBFH_ses-baselineYear1Arm1 -tp sub-NDARINVR24ACBFH_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR24ACBFH_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR24ACBFH_long -tp sub-NDARINVR24ACBFH_ses-baselineYear1Arm1 -tp sub-NDARINVR24ACBFH_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR268FVXE_long -tp sub-NDARINVR268FVXE_ses-baselineYear1Arm1 -tp sub-NDARINVR268FVXE_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR268FVXE_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR268FVXE_long -tp sub-NDARINVR268FVXE_ses-baselineYear1Arm1 -tp sub-NDARINVR268FVXE_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR27YCM3P_long -tp sub-NDARINVR27YCM3P_ses-baselineYear1Arm1 -tp sub-NDARINVR27YCM3P_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR27YCM3P_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR27YCM3P_long -tp sub-NDARINVR27YCM3P_ses-baselineYear1Arm1 -tp sub-NDARINVR27YCM3P_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR28A45T6_long -tp sub-NDARINVR28A45T6_ses-baselineYear1Arm1 -tp sub-NDARINVR28A45T6_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR28A45T6_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR28A45T6_long -tp sub-NDARINVR28A45T6_ses-baselineYear1Arm1 -tp sub-NDARINVR28A45T6_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR29UPFWC_long -tp sub-NDARINVR29UPFWC_ses-baselineYear1Arm1 -tp sub-NDARINVR29UPFWC_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR29UPFWC_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR29UPFWC_long -tp sub-NDARINVR29UPFWC_ses-baselineYear1Arm1 -tp sub-NDARINVR29UPFWC_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR2AB103B_long -tp sub-NDARINVR2AB103B_ses-baselineYear1Arm1 -tp sub-NDARINVR2AB103B_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR2AB103B_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR2AB103B_long -tp sub-NDARINVR2AB103B_ses-baselineYear1Arm1 -tp sub-NDARINVR2AB103B_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR2EC067F_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVR2EC067F_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR2HJCC0M_long -tp sub-NDARINVR2HJCC0M_ses-baselineYear1Arm1 -tp sub-NDARINVR2HJCC0M_ses-2YearFollowUpYArm1 -tp sub-NDARINVR2HJCC0M_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR2HJCC0M_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR2HJCC0M_long -tp sub-NDARINVR2HJCC0M_ses-baselineYear1Arm1 -tp sub-NDARINVR2HJCC0M_ses-2YearFollowUpYArm1 -tp sub-NDARINVR2HJCC0M_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR2JZ1RD8_long -tp sub-NDARINVR2JZ1RD8_ses-baselineYear1Arm1 -tp sub-NDARINVR2JZ1RD8_ses-2YearFollowUpYArm1 -tp sub-NDARINVR2JZ1RD8_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR2JZ1RD8_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR2JZ1RD8_long -tp sub-NDARINVR2JZ1RD8_ses-baselineYear1Arm1 -tp sub-NDARINVR2JZ1RD8_ses-2YearFollowUpYArm1 -tp sub-NDARINVR2JZ1RD8_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR2R52JP7_long -tp sub-NDARINVR2R52JP7_ses-baselineYear1Arm1 -tp sub-NDARINVR2R52JP7_ses-2YearFollowUpYArm1 -tp sub-NDARINVR2R52JP7_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR2R52JP7_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR2R52JP7_long -tp sub-NDARINVR2R52JP7_ses-baselineYear1Arm1 -tp sub-NDARINVR2R52JP7_ses-2YearFollowUpYArm1 -tp sub-NDARINVR2R52JP7_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR2T9NUK9_long -tp sub-NDARINVR2T9NUK9_ses-baselineYear1Arm1 -tp sub-NDARINVR2T9NUK9_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR2T9NUK9_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR2T9NUK9_long -tp sub-NDARINVR2T9NUK9_ses-baselineYear1Arm1 -tp sub-NDARINVR2T9NUK9_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR2TNT1JG_long -tp sub-NDARINVR2TNT1JG_ses-baselineYear1Arm1 -tp sub-NDARINVR2TNT1JG_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR2TNT1JG_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR2TNT1JG_long -tp sub-NDARINVR2TNT1JG_ses-baselineYear1Arm1 -tp sub-NDARINVR2TNT1JG_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3ABLBEY_long -tp sub-NDARINVR3ABLBEY_ses-baselineYear1Arm1 -tp sub-NDARINVR3ABLBEY_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3ABLBEY_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3ABLBEY_long -tp sub-NDARINVR3ABLBEY_ses-baselineYear1Arm1 -tp sub-NDARINVR3ABLBEY_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3CBHF7B_long -tp sub-NDARINVR3CBHF7B_ses-baselineYear1Arm1 -tp sub-NDARINVR3CBHF7B_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3CBHF7B_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3CBHF7B_long -tp sub-NDARINVR3CBHF7B_ses-baselineYear1Arm1 -tp sub-NDARINVR3CBHF7B_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3G28E6R_long -tp sub-NDARINVR3G28E6R_ses-baselineYear1Arm1 -tp sub-NDARINVR3G28E6R_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3G28E6R_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3G28E6R_long -tp sub-NDARINVR3G28E6R_ses-baselineYear1Arm1 -tp sub-NDARINVR3G28E6R_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3GH8J7X_long -tp sub-NDARINVR3GH8J7X_ses-baselineYear1Arm1 -tp sub-NDARINVR3GH8J7X_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3GH8J7X_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3GH8J7X_long -tp sub-NDARINVR3GH8J7X_ses-baselineYear1Arm1 -tp sub-NDARINVR3GH8J7X_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3JXE4GH_long -tp sub-NDARINVR3JXE4GH_ses-baselineYear1Arm1 -tp sub-NDARINVR3JXE4GH_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3JXE4GH_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3JXE4GH_long -tp sub-NDARINVR3JXE4GH_ses-baselineYear1Arm1 -tp sub-NDARINVR3JXE4GH_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3NZ8ZKA_long -tp sub-NDARINVR3NZ8ZKA_ses-baselineYear1Arm1 -tp sub-NDARINVR3NZ8ZKA_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3NZ8ZKA_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3NZ8ZKA_long -tp sub-NDARINVR3NZ8ZKA_ses-baselineYear1Arm1 -tp sub-NDARINVR3NZ8ZKA_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR3T709BD_ses-3YearFollowUpYArm1
# recon-all -base  sub-NDARINVR3T709BD_long -tp sub-NDARINVR3T709BD_ses-baselineYear1Arm1 -tp sub-NDARINVR3T709BD_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3T709BD_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3T709BD_long -tp sub-NDARINVR3T709BD_ses-baselineYear1Arm1 -tp sub-NDARINVR3T709BD_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3VTVCE5_long -tp sub-NDARINVR3VTVCE5_ses-baselineYear1Arm1 -tp sub-NDARINVR3VTVCE5_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3VTVCE5_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3VTVCE5_long -tp sub-NDARINVR3VTVCE5_ses-baselineYear1Arm1 -tp sub-NDARINVR3VTVCE5_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR3ZE9RGY_long -tp sub-NDARINVR3ZE9RGY_ses-baselineYear1Arm1 -tp sub-NDARINVR3ZE9RGY_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR3ZE9RGY_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR3ZE9RGY_long -tp sub-NDARINVR3ZE9RGY_ses-baselineYear1Arm1 -tp sub-NDARINVR3ZE9RGY_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR40EH36N_long -tp sub-NDARINVR40EH36N_ses-baselineYear1Arm1 -tp sub-NDARINVR40EH36N_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR40EH36N_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR40EH36N_long -tp sub-NDARINVR40EH36N_ses-baselineYear1Arm1 -tp sub-NDARINVR40EH36N_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR44LUUEZ_long -tp sub-NDARINVR44LUUEZ_ses-baselineYear1Arm1 -tp sub-NDARINVR44LUUEZ_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR44LUUEZ_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR44LUUEZ_long -tp sub-NDARINVR44LUUEZ_ses-baselineYear1Arm1 -tp sub-NDARINVR44LUUEZ_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR4EUGHE9_long -tp sub-NDARINVR4EUGHE9_ses-baselineYear1Arm1 -tp sub-NDARINVR4EUGHE9_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR4EUGHE9_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR4EUGHE9_long -tp sub-NDARINVR4EUGHE9_ses-baselineYear1Arm1 -tp sub-NDARINVR4EUGHE9_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR4PV7WZ3_long -tp sub-NDARINVR4PV7WZ3_ses-baselineYear1Arm1 -tp sub-NDARINVR4PV7WZ3_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR4PV7WZ3_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR4PV7WZ3_long -tp sub-NDARINVR4PV7WZ3_ses-baselineYear1Arm1 -tp sub-NDARINVR4PV7WZ3_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR547JUTN_long -tp sub-NDARINVR547JUTN_ses-baselineYear1Arm1 -tp sub-NDARINVR547JUTN_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR547JUTN_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR547JUTN_long -tp sub-NDARINVR547JUTN_ses-baselineYear1Arm1 -tp sub-NDARINVR547JUTN_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR57RHGC2_long -tp sub-NDARINVR57RHGC2_ses-baselineYear1Arm1 -tp sub-NDARINVR57RHGC2_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR57RHGC2_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR57RHGC2_long -tp sub-NDARINVR57RHGC2_ses-baselineYear1Arm1 -tp sub-NDARINVR57RHGC2_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR5EL81TR_long -tp sub-NDARINVR5EL81TR_ses-baselineYear1Arm1 -tp sub-NDARINVR5EL81TR_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR5EL81TR_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR5EL81TR_long -tp sub-NDARINVR5EL81TR_ses-baselineYear1Arm1 -tp sub-NDARINVR5EL81TR_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR5FD0UXH_long -tp sub-NDARINVR5FD0UXH_ses-baselineYear1Arm1 -tp sub-NDARINVR5FD0UXH_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR5FD0UXH_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR5FD0UXH_long -tp sub-NDARINVR5FD0UXH_ses-baselineYear1Arm1 -tp sub-NDARINVR5FD0UXH_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR5TTP09Z_long -tp sub-NDARINVR5TTP09Z_ses-baselineYear1Arm1 -tp sub-NDARINVR5TTP09Z_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR5TTP09Z_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR5TTP09Z_long -tp sub-NDARINVR5TTP09Z_ses-baselineYear1Arm1 -tp sub-NDARINVR5TTP09Z_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR5UHTTD8_long -tp sub-NDARINVR5UHTTD8_ses-baselineYear1Arm1 -tp sub-NDARINVR5UHTTD8_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR5UHTTD8_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR5UHTTD8_long -tp sub-NDARINVR5UHTTD8_ses-baselineYear1Arm1 -tp sub-NDARINVR5UHTTD8_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR5VKKRM9_long -tp sub-NDARINVR5VKKRM9_ses-baselineYear1Arm1 -tp sub-NDARINVR5VKKRM9_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR5VKKRM9_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR5VKKRM9_long -tp sub-NDARINVR5VKKRM9_ses-baselineYear1Arm1 -tp sub-NDARINVR5VKKRM9_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR62XCRKN_long -tp sub-NDARINVR62XCRKN_ses-baselineYear1Arm1 -tp sub-NDARINVR62XCRKN_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR62XCRKN_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR62XCRKN_long -tp sub-NDARINVR62XCRKN_ses-baselineYear1Arm1 -tp sub-NDARINVR62XCRKN_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR64BGK81_long -tp sub-NDARINVR64BGK81_ses-baselineYear1Arm1 -tp sub-NDARINVR64BGK81_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR64BGK81_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR64BGK81_long -tp sub-NDARINVR64BGK81_ses-baselineYear1Arm1 -tp sub-NDARINVR64BGK81_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR65NNDD4_long -tp sub-NDARINVR65NNDD4_ses-baselineYear1Arm1 -tp sub-NDARINVR65NNDD4_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR65NNDD4_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR65NNDD4_long -tp sub-NDARINVR65NNDD4_ses-baselineYear1Arm1 -tp sub-NDARINVR65NNDD4_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR69CJC9E_long -tp sub-NDARINVR69CJC9E_ses-baselineYear1Arm1 -tp sub-NDARINVR69CJC9E_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR69CJC9E_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR69CJC9E_long -tp sub-NDARINVR69CJC9E_ses-baselineYear1Arm1 -tp sub-NDARINVR69CJC9E_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR6CE8KZ5_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVR6CE8KZ5_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR6FAP3A7_long -tp sub-NDARINVR6FAP3A7_ses-baselineYear1Arm1 -tp sub-NDARINVR6FAP3A7_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR6FAP3A7_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR6FAP3A7_long -tp sub-NDARINVR6FAP3A7_ses-baselineYear1Arm1 -tp sub-NDARINVR6FAP3A7_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR6PPY0VL_long -tp sub-NDARINVR6PPY0VL_ses-baselineYear1Arm1 -tp sub-NDARINVR6PPY0VL_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR6PPY0VL_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR6PPY0VL_long -tp sub-NDARINVR6PPY0VL_ses-baselineYear1Arm1 -tp sub-NDARINVR6PPY0VL_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR6R9DHFF_long -tp sub-NDARINVR6R9DHFF_ses-baselineYear1Arm1 -tp sub-NDARINVR6R9DHFF_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR6R9DHFF_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR6R9DHFF_long -tp sub-NDARINVR6R9DHFF_ses-baselineYear1Arm1 -tp sub-NDARINVR6R9DHFF_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR6TLLPMG_long -tp sub-NDARINVR6TLLPMG_ses-baselineYear1Arm1 -tp sub-NDARINVR6TLLPMG_ses-2YearFollowUpYArm1 -tp sub-NDARINVR6TLLPMG_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR6TLLPMG_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR6TLLPMG_long -tp sub-NDARINVR6TLLPMG_ses-baselineYear1Arm1 -tp sub-NDARINVR6TLLPMG_ses-2YearFollowUpYArm1 -tp sub-NDARINVR6TLLPMG_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR6V7FU8U_long -tp sub-NDARINVR6V7FU8U_ses-baselineYear1Arm1 -tp sub-NDARINVR6V7FU8U_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR6V7FU8U_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR6V7FU8U_long -tp sub-NDARINVR6V7FU8U_ses-baselineYear1Arm1 -tp sub-NDARINVR6V7FU8U_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR6YF8VHD_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVR6YF8VHD_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR6ZXCFE9_long -tp sub-NDARINVR6ZXCFE9_ses-baselineYear1Arm1 -tp sub-NDARINVR6ZXCFE9_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR6ZXCFE9_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR6ZXCFE9_long -tp sub-NDARINVR6ZXCFE9_ses-baselineYear1Arm1 -tp sub-NDARINVR6ZXCFE9_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR76W27PF_ses-2YearFollowUpYArm1
#  > Only one timepoint for sub-NDARINVR76W27PF_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR792CLE6_long -tp sub-NDARINVR792CLE6_ses-baselineYear1Arm1 -tp sub-NDARINVR792CLE6_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR792CLE6_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR792CLE6_long -tp sub-NDARINVR792CLE6_ses-baselineYear1Arm1 -tp sub-NDARINVR792CLE6_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR7G6JDFU_long -tp sub-NDARINVR7G6JDFU_ses-baselineYear1Arm1 -tp sub-NDARINVR7G6JDFU_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR7G6JDFU_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR7G6JDFU_long -tp sub-NDARINVR7G6JDFU_ses-baselineYear1Arm1 -tp sub-NDARINVR7G6JDFU_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR7GMKJ6J_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVR7GMKJ6J_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR7HEU5W3_long -tp sub-NDARINVR7HEU5W3_ses-baselineYear1Arm1 -tp sub-NDARINVR7HEU5W3_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR7HEU5W3_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR7HEU5W3_long -tp sub-NDARINVR7HEU5W3_ses-baselineYear1Arm1 -tp sub-NDARINVR7HEU5W3_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR7N0XBL6_long -tp sub-NDARINVR7N0XBL6_ses-baselineYear1Arm1 -tp sub-NDARINVR7N0XBL6_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR7N0XBL6_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR7N0XBL6_long -tp sub-NDARINVR7N0XBL6_ses-baselineYear1Arm1 -tp sub-NDARINVR7N0XBL6_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR7WFN9E7_ses-2YearFollowUpYArm1
#  > Only one timepoint for sub-NDARINVR7WFN9E7_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR81CF71A_long -tp sub-NDARINVR81CF71A_ses-baselineYear1Arm1 -tp sub-NDARINVR81CF71A_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR81CF71A_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR81CF71A_long -tp sub-NDARINVR81CF71A_ses-baselineYear1Arm1 -tp sub-NDARINVR81CF71A_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR81GJYNH_long -tp sub-NDARINVR81GJYNH_ses-baselineYear1Arm1 -tp sub-NDARINVR81GJYNH_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR81GJYNH_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR81GJYNH_long -tp sub-NDARINVR81GJYNH_ses-baselineYear1Arm1 -tp sub-NDARINVR81GJYNH_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVR85P7XPP_ses-baselineYear1Arm1
#  > Freesurfer did not complete for sub-NDARINVR85P7XPP_ses-2YearFollowUpYArm1
#  > Only one timepoint for sub-NDARINVR85P7XPP_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVR8EDKZ2W_long -tp sub-NDARINVR8EDKZ2W_ses-baselineYear1Arm1 -tp sub-NDARINVR8EDKZ2W_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR8EDKZ2W_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR8EDKZ2W_long -tp sub-NDARINVR8EDKZ2W_ses-baselineYear1Arm1 -tp sub-NDARINVR8EDKZ2W_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR8F6YH4J_long -tp sub-NDARINVR8F6YH4J_ses-baselineYear1Arm1 -tp sub-NDARINVR8F6YH4J_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR8F6YH4J_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR8F6YH4J_long -tp sub-NDARINVR8F6YH4J_ses-baselineYear1Arm1 -tp sub-NDARINVR8F6YH4J_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR8LMF308_long -tp sub-NDARINVR8LMF308_ses-baselineYear1Arm1 -tp sub-NDARINVR8LMF308_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR8LMF308_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR8LMF308_long -tp sub-NDARINVR8LMF308_ses-baselineYear1Arm1 -tp sub-NDARINVR8LMF308_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR9A6L5EN_long -tp sub-NDARINVR9A6L5EN_ses-baselineYear1Arm1 -tp sub-NDARINVR9A6L5EN_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR9A6L5EN_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR9A6L5EN_long -tp sub-NDARINVR9A6L5EN_ses-baselineYear1Arm1 -tp sub-NDARINVR9A6L5EN_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR9ACLAJX_long -tp sub-NDARINVR9ACLAJX_ses-baselineYear1Arm1 -tp sub-NDARINVR9ACLAJX_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR9ACLAJX_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR9ACLAJX_long -tp sub-NDARINVR9ACLAJX_ses-baselineYear1Arm1 -tp sub-NDARINVR9ACLAJX_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR9AJ27WZ_long -tp sub-NDARINVR9AJ27WZ_ses-baselineYear1Arm1 -tp sub-NDARINVR9AJ27WZ_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR9AJ27WZ_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR9AJ27WZ_long -tp sub-NDARINVR9AJ27WZ_ses-baselineYear1Arm1 -tp sub-NDARINVR9AJ27WZ_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR9BWXYKD_long -tp sub-NDARINVR9BWXYKD_ses-baselineYear1Arm1 -tp sub-NDARINVR9BWXYKD_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR9BWXYKD_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR9BWXYKD_long -tp sub-NDARINVR9BWXYKD_ses-baselineYear1Arm1 -tp sub-NDARINVR9BWXYKD_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR9JZP8TC_long -tp sub-NDARINVR9JZP8TC_ses-baselineYear1Arm1 -tp sub-NDARINVR9JZP8TC_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR9JZP8TC_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR9JZP8TC_long -tp sub-NDARINVR9JZP8TC_ses-baselineYear1Arm1 -tp sub-NDARINVR9JZP8TC_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR9LMGEVE_long -tp sub-NDARINVR9LMGEVE_ses-baselineYear1Arm1 -tp sub-NDARINVR9LMGEVE_ses-2YearFollowUpYArm1 -tp sub-NDARINVR9LMGEVE_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR9LMGEVE_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR9LMGEVE_long -tp sub-NDARINVR9LMGEVE_ses-baselineYear1Arm1 -tp sub-NDARINVR9LMGEVE_ses-2YearFollowUpYArm1 -tp sub-NDARINVR9LMGEVE_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVR9Z48Y9H_long -tp sub-NDARINVR9Z48Y9H_ses-baselineYear1Arm1 -tp sub-NDARINVR9Z48Y9H_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVR9Z48Y9H_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVR9Z48Y9H_long -tp sub-NDARINVR9Z48Y9H_ses-baselineYear1Arm1 -tp sub-NDARINVR9Z48Y9H_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRAFYUKZZ_long -tp sub-NDARINVRAFYUKZZ_ses-baselineYear1Arm1 -tp sub-NDARINVRAFYUKZZ_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRAFYUKZZ_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRAFYUKZZ_long -tp sub-NDARINVRAFYUKZZ_ses-baselineYear1Arm1 -tp sub-NDARINVRAFYUKZZ_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRALE29MJ_long -tp sub-NDARINVRALE29MJ_ses-baselineYear1Arm1 -tp sub-NDARINVRALE29MJ_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRALE29MJ_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRALE29MJ_long -tp sub-NDARINVRALE29MJ_ses-baselineYear1Arm1 -tp sub-NDARINVRALE29MJ_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRAR30NKY_long -tp sub-NDARINVRAR30NKY_ses-baselineYear1Arm1 -tp sub-NDARINVRAR30NKY_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRAR30NKY_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRAR30NKY_long -tp sub-NDARINVRAR30NKY_ses-baselineYear1Arm1 -tp sub-NDARINVRAR30NKY_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRAZNX234_long -tp sub-NDARINVRAZNX234_ses-baselineYear1Arm1 -tp sub-NDARINVRAZNX234_ses-2YearFollowUpYArm1 -tp sub-NDARINVRAZNX234_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRAZNX234_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRAZNX234_long -tp sub-NDARINVRAZNX234_ses-baselineYear1Arm1 -tp sub-NDARINVRAZNX234_ses-2YearFollowUpYArm1 -tp sub-NDARINVRAZNX234_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRAZRBGAL_long -tp sub-NDARINVRAZRBGAL_ses-baselineYear1Arm1 -tp sub-NDARINVRAZRBGAL_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRAZRBGAL_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRAZRBGAL_long -tp sub-NDARINVRAZRBGAL_ses-baselineYear1Arm1 -tp sub-NDARINVRAZRBGAL_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRB41RYA0_long -tp sub-NDARINVRB41RYA0_ses-baselineYear1Arm1 -tp sub-NDARINVRB41RYA0_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRB41RYA0_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRB41RYA0_long -tp sub-NDARINVRB41RYA0_ses-baselineYear1Arm1 -tp sub-NDARINVRB41RYA0_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVRBJT537E_ses-3YearFollowUpYArm1
# recon-all -base  sub-NDARINVRBJT537E_long -tp sub-NDARINVRBJT537E_ses-baselineYear1Arm1 -tp sub-NDARINVRBJT537E_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRBJT537E_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRBJT537E_long -tp sub-NDARINVRBJT537E_ses-baselineYear1Arm1 -tp sub-NDARINVRBJT537E_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVRBNRB1DU_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVRBNRB1DU_ses-2YearFollowUpYArm1 aborting.
#  > Freesurfer did not complete for sub-NDARINVRBNTNJKT_ses-2YearFollowUpYArm1
#  > Only one timepoint for sub-NDARINVRBNTNJKT_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVRBPWCYVX_long -tp sub-NDARINVRBPWCYVX_ses-baselineYear1Arm1 -tp sub-NDARINVRBPWCYVX_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRBPWCYVX_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRBPWCYVX_long -tp sub-NDARINVRBPWCYVX_ses-baselineYear1Arm1 -tp sub-NDARINVRBPWCYVX_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVRBUNMARM_ses-4YearFollowUpYArm1
# recon-all -base  sub-NDARINVRBUNMARM_long -tp sub-NDARINVRBUNMARM_ses-baselineYear1Arm1 -tp sub-NDARINVRBUNMARM_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRBUNMARM_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRBUNMARM_long -tp sub-NDARINVRBUNMARM_ses-baselineYear1Arm1 -tp sub-NDARINVRBUNMARM_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVRBVRP43D_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVRBVRP43D_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVRC238TRX_long -tp sub-NDARINVRC238TRX_ses-baselineYear1Arm1 -tp sub-NDARINVRC238TRX_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRC238TRX_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRC238TRX_long -tp sub-NDARINVRC238TRX_ses-baselineYear1Arm1 -tp sub-NDARINVRC238TRX_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVRC3GEEEJ_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVRC3GEEEJ_ses-2YearFollowUpYArm1 aborting.
#  > Freesurfer did not complete for sub-NDARINVRCB6GG4P_ses-2YearFollowUpYArm1
#  > Only one timepoint for sub-NDARINVRCB6GG4P_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVRCE62M22_long -tp sub-NDARINVRCE62M22_ses-baselineYear1Arm1 -tp sub-NDARINVRCE62M22_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRCE62M22_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRCE62M22_long -tp sub-NDARINVRCE62M22_ses-baselineYear1Arm1 -tp sub-NDARINVRCE62M22_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRCFHLNK7_long -tp sub-NDARINVRCFHLNK7_ses-baselineYear1Arm1 -tp sub-NDARINVRCFHLNK7_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVRCFHLNK7_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVRCFHLNK7_long -tp sub-NDARINVRCFHLNK7_ses-baselineYear1Arm1 -tp sub-NDARINVRCFHLNK7_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVRCGDPDYL_long -tp sub-NDARINVRCGDPDYL_ses-baselineYear1Arm1 -tp sub-NDARINVRCGDPDYL_ses-2YearFollowUpYArm1 -all -qcache
# ...
# recon-all -base  sub-NDARINVZWP490TG_long -tp sub-NDARINVZWP490TG_ses-baselineYear1Arm1 -tp sub-NDARINVZWP490TG_ses-2YearFollowUpYArm1 -tp sub-NDARINVZWP490TG_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZWP490TG_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZWP490TG_long -tp sub-NDARINVZWP490TG_ses-baselineYear1Arm1 -tp sub-NDARINVZWP490TG_ses-2YearFollowUpYArm1 -tp sub-NDARINVZWP490TG_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZWRJXNHE_long -tp sub-NDARINVZWRJXNHE_ses-baselineYear1Arm1 -tp sub-NDARINVZWRJXNHE_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZWRJXNHE_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZWRJXNHE_long -tp sub-NDARINVZWRJXNHE_ses-baselineYear1Arm1 -tp sub-NDARINVZWRJXNHE_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZWWDT1TG_long -tp sub-NDARINVZWWDT1TG_ses-baselineYear1Arm1 -tp sub-NDARINVZWWDT1TG_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZWWDT1TG_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZWWDT1TG_long -tp sub-NDARINVZWWDT1TG_ses-baselineYear1Arm1 -tp sub-NDARINVZWWDT1TG_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZX24TGXN_long -tp sub-NDARINVZX24TGXN_ses-baselineYear1Arm1 -tp sub-NDARINVZX24TGXN_ses-2YearFollowUpYArm1 -tp sub-NDARINVZX24TGXN_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZX24TGXN_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZX24TGXN_long -tp sub-NDARINVZX24TGXN_ses-baselineYear1Arm1 -tp sub-NDARINVZX24TGXN_ses-2YearFollowUpYArm1 -tp sub-NDARINVZX24TGXN_ses-4YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVZXC2YRV3_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVZXC2YRV3_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVZXF5C635_long -tp sub-NDARINVZXF5C635_ses-baselineYear1Arm1 -tp sub-NDARINVZXF5C635_ses-2YearFollowUpYArm1 -tp sub-NDARINVZXF5C635_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZXF5C635_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZXF5C635_long -tp sub-NDARINVZXF5C635_ses-baselineYear1Arm1 -tp sub-NDARINVZXF5C635_ses-2YearFollowUpYArm1 -tp sub-NDARINVZXF5C635_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZXHZPZ48_long -tp sub-NDARINVZXHZPZ48_ses-baselineYear1Arm1 -tp sub-NDARINVZXHZPZ48_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZXHZPZ48_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZXHZPZ48_long -tp sub-NDARINVZXHZPZ48_ses-baselineYear1Arm1 -tp sub-NDARINVZXHZPZ48_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZXL36BR5_long -tp sub-NDARINVZXL36BR5_ses-baselineYear1Arm1 -tp sub-NDARINVZXL36BR5_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZXL36BR5_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZXL36BR5_long -tp sub-NDARINVZXL36BR5_ses-baselineYear1Arm1 -tp sub-NDARINVZXL36BR5_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZXL47HRG_long -tp sub-NDARINVZXL47HRG_ses-baselineYear1Arm1 -tp sub-NDARINVZXL47HRG_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZXL47HRG_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZXL47HRG_long -tp sub-NDARINVZXL47HRG_ses-baselineYear1Arm1 -tp sub-NDARINVZXL47HRG_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZXPAWB32_long -tp sub-NDARINVZXPAWB32_ses-baselineYear1Arm1 -tp sub-NDARINVZXPAWB32_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZXPAWB32_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZXPAWB32_long -tp sub-NDARINVZXPAWB32_ses-baselineYear1Arm1 -tp sub-NDARINVZXPAWB32_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZYB94X1J_long -tp sub-NDARINVZYB94X1J_ses-baselineYear1Arm1 -tp sub-NDARINVZYB94X1J_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZYB94X1J_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZYB94X1J_long -tp sub-NDARINVZYB94X1J_ses-baselineYear1Arm1 -tp sub-NDARINVZYB94X1J_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZYF317MG_long -tp sub-NDARINVZYF317MG_ses-baselineYear1Arm1 -tp sub-NDARINVZYF317MG_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZYF317MG_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZYF317MG_long -tp sub-NDARINVZYF317MG_ses-baselineYear1Arm1 -tp sub-NDARINVZYF317MG_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZYLV9BMB_long -tp sub-NDARINVZYLV9BMB_ses-baselineYear1Arm1 -tp sub-NDARINVZYLV9BMB_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZYLV9BMB_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZYLV9BMB_long -tp sub-NDARINVZYLV9BMB_ses-baselineYear1Arm1 -tp sub-NDARINVZYLV9BMB_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZYRTFYRP_long -tp sub-NDARINVZYRTFYRP_ses-baselineYear1Arm1 -tp sub-NDARINVZYRTFYRP_ses-2YearFollowUpYArm1 -tp sub-NDARINVZYRTFYRP_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZYRTFYRP_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZYRTFYRP_long -tp sub-NDARINVZYRTFYRP_ses-baselineYear1Arm1 -tp sub-NDARINVZYRTFYRP_ses-2YearFollowUpYArm1 -tp sub-NDARINVZYRTFYRP_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZYTK0K1Y_long -tp sub-NDARINVZYTK0K1Y_ses-baselineYear1Arm1 -tp sub-NDARINVZYTK0K1Y_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZYTK0K1Y_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZYTK0K1Y_long -tp sub-NDARINVZYTK0K1Y_ses-baselineYear1Arm1 -tp sub-NDARINVZYTK0K1Y_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZ05KY5J_long -tp sub-NDARINVZZ05KY5J_ses-baselineYear1Arm1 -tp sub-NDARINVZZ05KY5J_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZ05KY5J_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZ05KY5J_long -tp sub-NDARINVZZ05KY5J_ses-baselineYear1Arm1 -tp sub-NDARINVZZ05KY5J_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVZZ1MNPK5_ses-baselineYear1Arm1
# recon-all -base  sub-NDARINVZZ1MNPK5_long -tp sub-NDARINVZZ1MNPK5_ses-2YearFollowUpYArm1 -tp sub-NDARINVZZ1MNPK5_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZ1MNPK5_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZ1MNPK5_long -tp sub-NDARINVZZ1MNPK5_ses-2YearFollowUpYArm1 -tp sub-NDARINVZZ1MNPK5_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZ3P1ZFJ_long -tp sub-NDARINVZZ3P1ZFJ_ses-baselineYear1Arm1 -tp sub-NDARINVZZ3P1ZFJ_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZ3P1ZFJ_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZ3P1ZFJ_long -tp sub-NDARINVZZ3P1ZFJ_ses-baselineYear1Arm1 -tp sub-NDARINVZZ3P1ZFJ_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZ4XNM65_long -tp sub-NDARINVZZ4XNM65_ses-baselineYear1Arm1 -tp sub-NDARINVZZ4XNM65_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZ4XNM65_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZ4XNM65_long -tp sub-NDARINVZZ4XNM65_ses-baselineYear1Arm1 -tp sub-NDARINVZZ4XNM65_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZ6ZJ2KY_long -tp sub-NDARINVZZ6ZJ2KY_ses-baselineYear1Arm1 -tp sub-NDARINVZZ6ZJ2KY_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZ6ZJ2KY_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZ6ZJ2KY_long -tp sub-NDARINVZZ6ZJ2KY_ses-baselineYear1Arm1 -tp sub-NDARINVZZ6ZJ2KY_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZ81LEEV_long -tp sub-NDARINVZZ81LEEV_ses-baselineYear1Arm1 -tp sub-NDARINVZZ81LEEV_ses-2YearFollowUpYArm1 -tp sub-NDARINVZZ81LEEV_ses-4YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZ81LEEV_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZ81LEEV_long -tp sub-NDARINVZZ81LEEV_ses-baselineYear1Arm1 -tp sub-NDARINVZZ81LEEV_ses-2YearFollowUpYArm1 -tp sub-NDARINVZZ81LEEV_ses-4YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZJ3A7BK_long -tp sub-NDARINVZZJ3A7BK_ses-baselineYear1Arm1 -tp sub-NDARINVZZJ3A7BK_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZJ3A7BK_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZJ3A7BK_long -tp sub-NDARINVZZJ3A7BK_ses-baselineYear1Arm1 -tp sub-NDARINVZZJ3A7BK_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZLZCKAY_long -tp sub-NDARINVZZLZCKAY_ses-baselineYear1Arm1 -tp sub-NDARINVZZLZCKAY_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZLZCKAY_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZLZCKAY_long -tp sub-NDARINVZZLZCKAY_ses-baselineYear1Arm1 -tp sub-NDARINVZZLZCKAY_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZNX6W2P_long -tp sub-NDARINVZZNX6W2P_ses-baselineYear1Arm1 -tp sub-NDARINVZZNX6W2P_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZNX6W2P_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZNX6W2P_long -tp sub-NDARINVZZNX6W2P_ses-baselineYear1Arm1 -tp sub-NDARINVZZNX6W2P_ses-2YearFollowUpYArm1 -all -qcache"
# recon-all -base  sub-NDARINVZZPKBDAC_long -tp sub-NDARINVZZPKBDAC_ses-baselineYear1Arm1 -tp sub-NDARINVZZPKBDAC_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZPKBDAC_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZPKBDAC_long -tp sub-NDARINVZZPKBDAC_ses-baselineYear1Arm1 -tp sub-NDARINVZZPKBDAC_ses-2YearFollowUpYArm1 -all -qcache"
#  > Freesurfer did not complete for sub-NDARINVZZZ2ALR6_ses-baselineYear1Arm1
#  > Only one timepoint for sub-NDARINVZZZ2ALR6_ses-2YearFollowUpYArm1 aborting.
# recon-all -base  sub-NDARINVZZZP87KR_long -tp sub-NDARINVZZZP87KR_ses-baselineYear1Arm1 -tp sub-NDARINVZZZP87KR_ses-2YearFollowUpYArm1 -all -qcache
# /home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py -length 202400 -memory 5gb -logfiledir /project_cephfs/3022017.02/logs -queue verylong -name ABCD_longfs_sub-NDARINVZZZP87KR_long -command "module load freesurfer/7.3.2 ;  export SUBJECTS_DIR=/project_cephfs/3022017.02/freesurfer ;  recon-all -base  sub-NDARINVZZZP87KR_long -tp sub-NDARINVZZZP87KR_ses-baselineYear1Arm1 -tp sub-NDARINVZZZP87KR_ses-2YearFollowUpYArm1 -all -qcache"
# jobs submitted = 1645
# number of subjects already processed = 0
# number failed = 0

# %%
full_subid
# Out:
# 'sub-NDARINVZZZP87KR_ses-2YearFollowUpYArm1'

# %% [markdown]
# ## Select subjects

# %%
fs_dir = os.path.join(root_dir,'freesurfer')
sub_dirs = glob.glob(os.path.join(fs_dir, '*_long'))

sub_list_target = []
for s in sub_dirs:
    subid = os.path.splitext(os.path.basename(s))[0].split('_')[0]
    
    sub_list_target.append(subid)
        
print(len(sub_list_target), 'subjects found')
sub_list_target[:10]
# Out:
# 6684 subjects found
# ['sub-NDARINVZKBLKU16',
#  'sub-NDARINVGY4WAXPR',
#  'sub-NDARINVB3L1EM9T',
#  'sub-NDARINV65HEDB50',
#  'sub-NDARINVCB2Z3BZD',
#  'sub-NDARINV4YH8H7KU',
#  'sub-NDARINVE3MEFJL5',
#  'sub-NDARINVTAX3MN8C',
#  'sub-NDARINVNGAXVYPV',
#  'sub-NDARINV2RD4CZ7T']

# %% [markdown]
# ## Run longitudinal freesurfer

# %%
num_processed = 0
num_failed = 0
num_submitted = 0
sub_no_t1 = []

verbose = True

log_prefix = 'ABCD_longfs2_'

sub_id_batch = sub_list_target[6000:]

#fs_env = 'export FREESURFER_HOME=/opt/freesurfer/7.3.2'
fs_env = 'module load freesurfer/7.3.2'

cmd_qsub_fs = ['/home/preclineu/andmar/DCCN/Scripts/Torque/SubmitToCluster.py',
                 '-length', '202400',
                 '-memory', '5gb',
                 '-logfiledir', cluster_log_dir,
                 '-queue verylong'
                ]

print('Processing', len(sub_id_batch), 'subjects ...')
for subid in sub_id_batch:
        
    sessions = glob.glob(os.path.join(fs_dir, f'{subid}_ses-*'))
    
    for full_subid in sessions:
        sesid = os.path.basename(full_subid)
        
        #if not os.path.exists(os.path.join(fs_dir, full_subid)):
        #    continue
                  
        out_dir = os.path.join(root_dir, 'freesurfer', full_subid)
            
        #if os.path.exists(out_dir):
        #    if os.path.exists(os.path.join(out_dir, 'stats', 'rh.w-g.pct.stats')):
        #        # analysis is complete
        #        if verbose:
        #            print(' > Freesurfer already run for', full_subid,'doing nothing')
        #        num_processed += 1
        #        continue
        #    else:
        #         # analysis did not complete
        #        num_failed +=1
        #        if verbose:
        #            print(' > Freesurfer subject',full_subid,'found but failed. Continuing analysis')
        #        cmd_fs = ['recon-all -long ', full_subid, f'{sub_id}_long', '-all','-qcache']
        #else:
            # no analysis has been run
            #if not os.path.exists(t1_file):
            #    if verbose: 
            #        print(' > No T1 found for sub', full_subid, '. Doing nothing')
            #    sub_no_t1.append(subid)
            #    continue
        
        cmd_fs = ['recon-all -long ', full_subid, f'{subid}_long', '-all','-qcache']
            
        #print(' '.join(cmd_fs))

        cmd_env = [fs_env + ' ; ',
                    'export SUBJECTS_DIR=' + fs_dir + ' ; ']
        cmd_str = '"%s"' % str(' '.join(cmd_env + cmd_fs)) 
        cmd_qsub = cmd_qsub_fs + ['-name', log_prefix + str(full_subid),'-command', cmd_str]
    
        num_submitted += 1
        print(' '.join(cmd_qsub))
        #subprocess.Popen(' '.join(cmd_qsub), shell=True)

print('jobs submitted =', num_submitted)       
print('number of subjects already processed =',num_processed)
print('number failed =',num_failed)
print('number without t1 =',len(sub_no_t1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 10
#       6 verbose = True
#       8 log_prefix = 'ABCD_longfs2_'
# ---> 10 sub_id_batch = sub_list_target[6000:]
#      12 #fs_env = 'export FREESURFER_HOME=/opt/freesurfer/7.3.2'
#      13 fs_env = 'module load freesurfer/7.3.2'
#
# NameError: name 'sub_list_target' is not defined
